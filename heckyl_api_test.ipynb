# %%
import pandas as pd
import requests
import json

# %%
payload = {
    'limit': 20,
    't': 'all'
}
headers = {
    'Authorization': 'ApiKey e5ac96cd-6010-4201-8cb0-661443072caa'
}

# %%
# # # For the purposes of demonstration, I will use the /r/funny subreddit

# # # endpoint = 'https://www.reddit.com/r/funny/top.json'

endpoint = "https://di.apidata.world/news/api/newsfeed/GetUniqueNews?entityTypeIds=1&languages=en&categoryIds=47&countryIds=1&lastNewsUpdateTime=1596546000000"

r = requests.get(endpoint, headers = headers, params = payload)

# %%
r = json.loads(r.content)

# %%
r.keys()
# Out:
# dict_keys(['newsItems', 'lastNewsUpdateTime', 'hasMoreNews'])

# %%
r['newsItems']['newsPublishedOn']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b44afcd5190b> in <module>
# ----> 1 r['newsItems']['newsPublishedOn']
#
# TypeError: list indices must be integers or slices, not str

# %%
r['newsItems']
# Out:
# 21272/AIN_twit_normal.jpg',
#   'newsPublishedOn': '2020-11-05T19:12:10Z',
#   'modifiedOn': '2020-11-05T19:12:30.213Z',
#   'entities': [{'entityId': 172049,
#     'entityTypeId': 5,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'India',
#     'entityTypeName': 'Country',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 885,
#     'entityTypeId': 1,
#     'entityCodes': ['INE776C01039', 'US3624501082'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'GMR INFRASTRUCTURE LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 1162726,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'GMR ENTERPRISES PVT LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 202429,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'DELHI INTERNATIONAL AIRPORT PVT LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'Crisis'}],
#   'language': 'en'},
#  {'newsId': 109060933,
#   'clusterIds': [47130875],
#   'title': '"Lab Reports Say Negative": Air India As 19 Test Positive On China Flight',
#   'description': 'New Delhi: Air India has reacted to reports that 19 Indians who flew to China\'s Wuhan - where the Covid pandemic originated in December last year - on a "Vande Bharat" flight on Friday tested positive for the virus on arrival.... This news comes via ChinaPulse.com, which delivers news, data, analysis, and insights on Chinese business, travel, finance, health, military, investment, and technology .',
#   'link': 'https://www.chinapulse.com/data-news/2020/11/06/lab-reports-say-negative-air-india-as-19-test-positive-on-china-flight-3/?utm_source=rss&utm_medium=rss&utm_campaign=lab-reports-say-negative-air-india-as-19-test-positive-on-china-flight-3',
#   'source': {'sourceId': 4815,
#    'sourceName': 'China Pulse',
#    'sourceUserName': None},
#   'imageUrl': None,
#   'newsPublishedOn': '2020-11-05T17:11:00Z',
#   'modifiedOn': '2020-11-05T21:08:29.644Z',
#   'entities': [{'entityId': 1151618,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'AIR INDIA LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 1.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': -0.6},
#    {'entityId': 195025,
#     'entityTypeId': 14,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'Air India',
#     'entityTypeName': 'Airline Name',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 1.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': -0.6},
#    {'entityId': 172093,
#     'entityTypeId': 5,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'China',
#     'entityTypeName': 'Country',
#     'positiveSentiment': 1.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.8}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'India and China'}],
#   'language': 'en'},
#  {'newsId': 109084807,
#   'clusterIds': [47140875],
#   'title': "Support in the crisis: Burger King calls on customers to order from McDonald's",
#   'description': 'When fast food giants advertise, they like to kid the competition. Most recently, Burger King showed the McDonald\'s clown as a scary figure. The rivalry between the two always creates entertaining moments for customers. But in the Corona crisis, not only bashing is popular. "We never thought we\'d say that ..." write the British marketing people from Burger King on Twitter - and recommend people go to McDonald\'s, Pizza Hut & Co. Burger King\'s Whopper is always the best choice, but ordering a Big Mac at McDonald\'s isn\'t that bad either. Because the restaurants with their thousands of employees are currently dependent on support. Burger King received a lot of praise from the Twitter community for the campaign. Almost 120,000 users liked the tweet. Fans of McDonald\'s, Kentucky Fried Chicken or Subway get in touch and thank Burger King for their selfless contribution. After the crisis, bashing should continue as usual. Does anyone else want to eat this? At the beginning of 2020, Burger King showed an advertisement in which the Whopper burger is not devoured by people, but by the insatiable maw of time. The result after 34 days: a unique mold culture that doesn\'t exactly make you want to bite into it. However, the aim of this global campaign is not to spoil our appetites, but quite the opposite: The American fast food chain wants to show its commitment to avoiding all artificial preservatives with the scruffy Whopper. The slogan of the Schimmel Whopper campaign even describes the high-resolution images of rotting food as "Beauty without artificial preservatives". In fact, Burger King soon wants to do without all artificial preservatives worldwide, which, according to the company, is already happening in large parts of Europe and at 400 locations in the USA.',
#   'link': 'https://www.archyworldys.com/support-in-the-crisis-burger-king-calls-on-customers-to-order-from-mcdonalds/',
#   'source': {'sourceId': 4714,
#    'sourceName': 'Archy Worldys',
#    'sourceUserName': None},
#   'imageUrl': None,
#   'newsPublishedOn': '2020-11-06T00:54:07Z',
#   'modifiedOn': '2020-11-06T00:59:08.373Z',
#   'entities': [{'entityId': 19760,
#     'entityTypeId': 1,
#     'entityCodes': ['CA76131D1033'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'RESTAURANT BRANDS INTERNATIONAL INC',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 1.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.4},
#    {'entityId': 6816049,
#     'entityTypeId': 17,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'BURGER KING',
#     'entityTypeName': 'Brand',
#     'positiveSentiment': 1.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.4},
#    {'entityId': 1152093,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'BURGER KING INDIA LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 1.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.4},
#    {'entityId': 5039,
#     'entityTypeId': 1,
#     'entityCodes': ['US5801351017', 'ARDEUT110269', 'BRMCDCBDR000'],
#     'entityCodeType': 'ISIN',
#     'entityName': "MCDONALD'S CORP",
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'Crisis'},
#    {'categoryId': 3, 'categoryName': 'Corporate Growth', 'keyword': 'Order'}],
#   'language': 'en'},
#  {'newsId': 109118901,
#   'clusterIds': [47107599],
#   'title': 'Hindustan Unilever Limited unleashes the superpower of nature through its new homecare brand, Nature Protect',
#   'description': 'The brand includes a range of innovative hygiene products that are infused with neem extract and naturally derived active With the new normal posing unknown hygiene and safety challenges, the need for a sustained hygiene solution that is built for the new reality has never been more pertinent. Unleashing the superpower of nature, Hindustan Unilever Limited, the largest fast-moving consumer goods (FMCG) company in India, launches Nature Protect. A range of innovative hygiene products infused with neem extract and naturally derived active, Nature Protect is specially formulated keeping in mind the current consumer requirements. With its product range proven to offer best in class germ protection, Nature Protect takes a 360-degree approach to hygiene effective in, on and around you, thereby standing as a safe solution to deliver hygiene anytime, anywhere. On You Around You In You Laundry detergent: Germ removal detergent powder Germ removal wipes: Made with 100% biodegradable fabric Germ- kill spray: For on-the-go protection; safe to use on surfaces and hands Disinfectant surface cleaner spray: Suitable to use on various surfaces in your home Disinfectant floor cleaner: Proven to kill 99.99% germs Disinfectant fruit & vegetable cleaner: Removes pesticides and kills 99.99% germs Talking about the launch, Sanjiv Mehta, Chairman and MD, Hindustan Unilever, said, " Hygiene has always been an important aspect of life but is now gaining paramount importance especially in times like these. Our research has shown that consumers are looking out for safe yet effective cleaning products, and their increased focus on hygiene is related to holistic wellbeing. It is imperative for us to reassess what has been accepted as routine practice and adopt a recalibrated approach that befits the new normal." Prabha Narasimhan, Executive Director - Home Care & Vice President - Home Care, Unilever South Asia, Hindustan Unilever, further added, "Consumers today have evolved in the journey from being intimidated by the threat to learning to live with it. They are becoming more conscious, seeking safer, more effective options in convenient formats that guarantee superior hygiene standards. Their cleaning behavior demands solutions that are created for specific touchpoints. Nature Protect is our one-stop range for all hygiene requirements that is powered by naturally derived active and neem. Consumers are aware of the power of nature and neem, that this range of hygiene products are crafted with while delivering impactful, effective results." Kajal Aggarwal said on the launch, "We have all given in to the fear and paranoia that has come with these tough times which also reflected in the message I had posted a couple of days back. As I turned a new chapter in my life just a couple of days back, I realized that change is the only constant and it is important to be more conscious about the need to find a safe and balanced solution for the evolved, new reality. I feel we need to be more mindful and adopt a hygiene solution that is sustainable and reassuring in the long run. It is time to be better armed to be able to give a befitting response to the current situation. Given that it addresses all my concerns and expectations, I believe in the proposition of Nature Protect. I feel it answers the bigger problem and is the perfect balance between efficiency and safety." Expressing her thoughts on the launch, PV Sindhu said, "We have been very passive in our approach towards hygiene and that was until the pandemic acted as an eyeopener. However, I feel we are still being very shortsighted and superficial and have been adopting a hygiene approach that is not wired for these extreme times. As an athlete, I have always strived hard to adapt to any situation. But, I think all of us need a stronger support system to thrive in the new normal The open letter that I had written aroused from this very thought and provoked me to believe that it\'s time to be  ...
#   'link': 'http://www.pitchonnet.com/blog/2020/11/06/hindustan-unilever-limited-unleashes-the-superpower-of-nature-through-its-new-homecare-brand-nature-protect/',
#   'source': {'sourceId': 2760,
#    'sourceName': 'Pitch On Net',
#    'sourceUserName': None},
#   'imageUrl': None,
#   'newsPublishedOn': '2020-11-06T07:16:01Z',
#   'modifiedOn': '2020-11-06T07:19:00.793Z',
#   'entities': [{'entityId': 1044,
#     'entityTypeId': 1,
#     'entityCodes': ['INE030A01027', 'US4332251093'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'HINDUSTAN UNILEVER LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'Superpower'}],
#   'language': 'en'},
#  {'newsId': 109124398,
#   'clusterIds': [47157936],
#   'title': "Concor's land licence fee dispute worsens, pressure mounts on the stock - Mint",
#   'description': "Concor's land licence fee dispute worsens, pressure mounts on the stock Mint",
#   'link': 'https://www.livemint.com/companies/news/concor-s-land-licence-fee-dispute-worsens-pressure-mounts-on-the-stock-11604644042406.html',
#   'source': {'sourceId': 4152,
#    'sourceName': 'News Aggregator',
#    'sourceUserName': None},
#   'imageUrl': None,
#   'newsPublishedOn': '2020-11-06T06:35:06Z',
#   'modifiedOn': '2020-11-06T08:11:55.427Z',
#   'entities': [{'entityId': 542,
#     'entityTypeId': 1,
#     'entityCodes': ['INE111A01025', 'US2107441089'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'CONTAINER CORP OF INDIA LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 8,
#     'categoryName': 'Legal',
#     'keyword': 'Dispute'},
#    {'categoryId': 47, 'categoryName': 'Geopolitical', 'keyword': 'Dispute'}],
#   'language': 'en'},
#  {'newsId': 109148943,
#   'clusterIds': [47121901],
#   'title': 'Thin Film Market Status & Industry Analysis 2019-2025 | Corning Incorporated, Kaneka Corporation, and EI du Pont, Umicore Group, American Elements, Ascent Solar Technologies, Moser Baer India Pvt. Ltd and China National Building Material Company Ltd - PRnews Leader',
#   'description': 'Thin Film Market Status & Industry Analysis 2019-2025 | Corning Incorporated, Kaneka Corporation, and EI du Pont, Umicore Group, American Elements, Ascent Solar Technologies, Moser Baer India Pvt. Ltd and China National Building Material Company Ltd PRnews Leader',
#   'link': 'https://prnewsleader.com/uncategorized/1671315/thin-film-market-status-industry-analysis-2019-2025-corning-incorporated-kaneka-corporation-and-e-i-du-pont-umicore-group-american-elements-ascent-solar-technologies-moser-baer-india-p/',
#   'source': {'sourceId': 4152,
#    'sourceName': 'News Aggregator',
#    'sourceUserName': None},
#   'imageUrl': None,
#   'newsPublishedOn': '2020-11-06T10:39:26Z',
#   'modifiedOn': '2020-11-06T11:45:32.355Z',
#   'entities': [{'entityId': 4817,
#     'entityTypeId': 1,
#     'entityCodes': ['US2193501051', 'ARDEUT111002'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'CORNING INC',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 4625,
#     'entityTypeId': 1,
#     'entityCodes': ['US2635341090', 'ARDEUT110145', 'BE0004069929'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'EI DU PONT DE NEMOURS & CO',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 172049,
#     'entityTypeId': 5,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'India',
#     'entityTypeName': 'Country',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 8869,
#     'entityTypeId': 1,
#     'entityCodes': ['CNE1000002N9', 'US16947K1079'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'CHINA NATIONAL BUILDING MATERIAL CO LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 5991,
#     'entityTypeId': 1,
#     'entityCodes': ['US0436354080'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'ASCENT SOLAR TECHNOLOGIES INC',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 7000304,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'TECHNOLOGIES INC',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 15132,
#     'entityTypeId': 1,
#     'entityCodes': ['BE0003884047', 'US90420M1045', 'BE0974320526'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'UMICORE',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 1644,
#     'entityTypeId': 1,
#     'entityCodes': ['INE739A01015', 'US61954P2011'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'MOSER BAER INDIA LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'India and China'}],
#   'language': 'en'},
#  {'newsId': 109164713,
#   'clusterIds': [47175896],
#   'title': "New documents show Trafigura threatened to block key funding to Europe's biggest #zinc smelter Nyrstar as it was fighting for survival amid a liquidity crisis. Trafigura later gained control of Nyrstar. @mburtonmetals @jfarchy #Belgium https://t.co/9sy5e7VOkF",
#   'description': None,
#   'link': 'https://t.co/9sy5e7VOkF',
#   'source': {'sourceId': 2311,
#    'sourceName': 'Twitter',
#    'sourceUserName': 'iamandyhoffman'},
#   'imageUrl': 'http://pbs.twimg.com/profile_images/738348655833452544/eWVaqiTY_normal.jpg',
#   'newsPublishedOn': '2020-11-06T13:41:14Z',
#   'modifiedOn': '2020-11-06T13:41:36.172Z',
#   'entities': [{'entityId': 65505,
#     'entityTypeId': 3,
#     'entityCodes': ['ZIN'],
#     'entityCodeType': 'COMMODITY',
#     'entityName': 'ZINC',
#     'entityTypeName': 'Commodity',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 3565458,
#     'entityTypeId': 10,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'ZINC',
#     'entityTypeName': 'Generic Drug',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 65625,
#     'entityTypeId': 8,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'Europe',
#     'entityTypeName': 'Region',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 15098,
#     'entityTypeId': 1,
#     'entityCodes': ['BE0974294267', 'US67077R1077'],
#     'entityCodeType': 'ISIN',
#     'entityName': 'NYRSTAR NV',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 172072,
#     'entityTypeId': 5,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'Belgium',
#     'entityTypeName': 'Country',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0},
#    {'entityId': 203582,
#     'entityTypeId': 1,
#     'entityCodes': [],
#     'entityCodeType': '',
#     'entityName': 'TRAFIGURA INDIA PVT LTD',
#     'entityTypeName': 'Company',
#     'positiveSentiment': 0.0,
#     'negativeSentiment': 0.0,
#     'neutralSentiment': 0.0,
#     'consolidatedSentiment': 0.0}],
#   'categories': [{'categoryId': 47,
#     'categoryName': 'Geopolitical',
#     'keyword': 'Crisis'}],
#   'language': 'en'}]

# %%
response_json = requests.get(endpoint, headers = headers, params = payload).json()
df = pd.DataFrame(response_json['dataset']['data'], columns = response_json['dataset']['column_names'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-4855d54fe150> in <module>
#       1 response_json = requests.get(endpoint, headers = headers, params = payload).json()
# ----> 2 df = pd.DataFrame(response_json['dataset']['data'], columns = response_json['dataset']['column_names'])
#       3 print(df)
#
# KeyError: 'dataset'
